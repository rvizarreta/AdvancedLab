# %%
# OPERATIONAL PACKAGES ---------------------------------------
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from math import inf
import scipy as sp

# STYLE RESOURCES ---------------------------------------
plt.style.reload_library()
plt.style.use(['science', 'grid'])

# FITTING PACKAGES ---------------------------------------
from lmfit import Model, Parameters

# %%
# DEFINING A FUNCTION THAT CLEANS THE DATA USING PETER'S NICE CODE ---------------------------------------
def CLEAN_INPUT(file):
    # cleaning superconductor data
    data = []
    clean_data = []

    # extract raw data
    f = open(file, 'r')
    for line in f:
        data.append(line)
    f.close()

    for i in range(0, len(data)):
        # broken apart by spaces
        temp = data[i].split(' ')
        if len(temp) == 3:
            clean_data.append(temp)
            # gets rid of newline in str
            clean_data[-1][-1] = clean_data[-1][-1].replace('\n','')

    # convert str to flt
    clean_data = np.array(clean_data, dtype = float)
    return clean_data

# FUNCTION FOR PLOTTING A SCATTER PLOT ---------------------------------------
def ScatterPlot(xdata,ydata,error_x,error_y,color,x_label,y_label):
    
    # SCATTER PLOT
    fig = plt.figure(figsize=(5, 5), dpi=80)
    plt.errorbar(xdata,ydata,yerr=error_y,capsize = 5,marker = 'o',markersize=4, linestyle = 'None',color='black')
    plt.errorbar(xdata,ydata,xerr=error_x,capsize = 5,marker = 'o',markersize=4, linestyle = 'None',color='black')
    
    title = r'$\textbf{' + y_label + ' vs ' + x_label + '}$'
    plt.xlabel(r'$\textit{'+ x_label +'}$', fontsize = 16)
    plt.ylabel(r'$\textit{'+ y_label +'}$', fontsize = 16)
    plt.ticklabel_format(axis="y", style="sci", scilimits=(0,0))
    plt.xticks(fontsize=15)
    plt.yticks(fontsize=15)
    plt.savefig("Figures/figure.png")
    
# DEFINING A FUNCTION THAT RETURNS THE UNCERTAINTY USING VARIATIONAL METHOD ---------------------------------------
def uncertainty_var(values, deltas, function):
    values, deltas = np.array(values), np.array(deltas)
    delta_matrix = deltas*np.identity(values.shape[0])
    sum = 0
    for delta in delta_matrix:
        sum += (0.5*(abs(function(values + delta) - function(values)) + abs(function(values-delta) - function(values))))**2
    return np.sqrt(sum)

# DEFINING A FUNCTION THAT CALCULATES THE RESISTANCE HAVING VOLTAGE AND CURRENT AS INPUTS ---------------------------------------
calculate_R = lambda param : abs(param[0]/param[1]) # param = [V, I]

# DEFINING THE SIGMOID FUNCTION ---------------------------------------
Sigmoid = lambda x, L ,x0, k : L/(1 + np.exp(-k*(x-x0))) 
# L: Height, k: steepness, x0: center

def FUNCTION_FIT(xdata, ydata, error_x, error_y, color, x_label, y_label, function):
    
    # Plotting scatter plot first
    ScatterPlot(xdata,ydata,error_x,error_y,color,x_label,y_label)
    
    # Fitting data using LMFIT
    gModel = Model(function)
    L ,x0, k = ydata.max(), np.median(xdata), 1 # Initial guess
    gModel.set_param_hint('L', value=L, min=0, max=inf)
    gModel.set_param_hint('x0', value=x0, min=0, max=inf)
    gModel.set_param_hint('k', value=k, min=0, max=inf)
    params = gModel.make_params()
    result = gModel.fit(ydata, x=xdata, L=L, x0=x0, k=k, weights=1/error_y)
    
    # Plotting Fitted Function
    L ,x0, k = result.params['L'].value, result.params['x0'].value, result.params['k'].value
    dx0 = result.params['x0'].stderr
    label = r'$\textit{(' + str("{:.5}".format(x0)) + '±' + str("{:.2}".format(dx0)) + ') K}$'
    #plt.plot(xdata,result.best_fit, color=color)
    x = np.arange(xdata.min(), xdata.max(), (xdata.max()-xdata.min())/1000) 
    plt.plot(x, function(x, L ,x0, k), color=color)
        
    #VERTICAL LINE 
    #plt.axvline(x=x0, color='k', linestyle='--', label=label)
    #plt.legend(prop={'size': 12}, loc=2)
    plt.savefig("Figures/figure.png")
    plt.show()
    
    # CALCULATING THE P-VALUE
    print('Corresponding p-value:',1.000-sp.stats.chi2.cdf(result.chisqr,result.nfree))
    print('Degrees of freedom:',result.nfree)
    
    # FIRST DERIVATIVE
    print('FIRST DERIVATIVE')
    fig = plt.figure(figsize=(5, 5), dpi=80)
    plt.xlabel(r'$\textit{'+ x_label +'}$', fontsize = 16)
    plt.ylabel(r'$\textit{First derivative}$', fontsize = 16)
    plt.ticklabel_format(axis="y", style="sci", scilimits=(0,0))
    plt.xticks(fontsize=15)
    plt.yticks(fontsize=15)
    y_prime = np.gradient(function(x, L ,x0, k))
    #deltax_prime = uncertainty_var(function(x, L ,x0, k), error_y, Sigmoid_inverse_der1(function(x, L ,x0, k), L ,x0, k))
    #plt.errorbar(x,y_prime,xerr=deltax_prime,capsize = 5,marker = 'o',markersize=4, linestyle = 'None',color='black')
    plt.plot(x, y_prime, color=color)
    plt.savefig("Figures/figure2.png")
    plt.show()
    
    # SECOND DERIVATIVE
    print('SECOND DERIVATIVE')
    fig = plt.figure(figsize=(5, 5), dpi=80)
    plt.xlabel(r'$\textit{'+ x_label +'}$', fontsize = 16)
    plt.ylabel(r'$\textit{Second derivative}$', fontsize = 16)
    plt.ticklabel_format(axis="y", style="sci", scilimits=(0,0))
    plt.xticks(fontsize=15)
    plt.yticks(fontsize=15)
    y_2prime = np.gradient(y_prime)
    plt.plot(x, y_2prime, color=color)
    
    # MAX RATE OF CHANGE
    x0 = x[np.where(y_2prime == y_2prime.max())][0]
    label = r'$\textit{(' + str("{:.5}".format(x0)) + '±' + str("{:.2}".format(dx0)) + ') K}$'
    plt.axvline(x=x0, color='k', linestyle='--', label=label)
    plt.legend(prop={'size': 12}, loc=3)
    plt.savefig("Figures/figure3.png")
    plt.show()

    return result

# %% [markdown]
# ***
# ### <font color=green>BUCKET 1 (WITH SUPERCONDUCTOR)</font>
# ***

# %% [markdown]
# # COOLING 1

# %%
# READING THE DATA FROM .txt FILES ---------------------------------------
data = CLEAN_INPUT('Week2Files/EvanRenzo_Cooling1.txt')
df = pd.DataFrame(data, columns=['I (mA)', 'Voltage (mV)', 'Temperature (K)'])
df['I (mA)'] = df['I (mA)']*1e2
df['Voltage (mV)'] = df['Voltage (mV)']*1e3
df['Resistance ($\Omega$)'] = df['Voltage (mV)']/df['I (mA)']
df = df[(df['Resistance ($\Omega$)']<1.25e-2) | (df['Resistance ($\Omega$)']>1.5e-2)] # Adjusting vertical range to fit data

# ADDING UNCERTAINTIES ---------------------------------------
df['$\Delta$ V (mV)'], df['$\Delta$ I (mA)'], df['$\Delta$ T (K)'] = 0.01, 0.01, 0.01
df['$\Delta$ R ($\Omega$)'] = df.apply(lambda x: uncertainty_var([x['Voltage (mV)'], x['I (mA)']], [x['$\Delta$ V (mV)'], x['$\Delta$ I (mA)']], calculate_R), axis=1)
df.head(5)
# Out:
#        I (mA)  Voltage (mV)  Temperature (K)  Resistance ($\Omega$)  \
# 0  100.073241      1.833901       215.157236               0.018326
# 1  100.069459      1.834235       215.181621               0.018330
# 2  100.069377      1.834668       215.202756               0.018334
# 3  100.064778      1.834620       215.173287               0.018334
# 4  100.068116      1.834379       215.076589               0.018331
#
#    $\Delta$ V (mV)  $\Delta$ I (mA)  $\Delta$ T (K)  $\Delta$ R ($\Omega$)
# 0             0.01             0.01            0.01                 0.0001
# 1             0.01             0.01            0.01                 0.0001
# 2             0.01             0.01            0.01                 0.0001
# 3             0.01             0.01            0.01                 0.0001
# 4             0.01             0.01            0.01                 0.0001

# %%
# PLOTTING OUR DATA
xdata, ydata, error_x, error_y = df['Temperature (K)'], df['Resistance ($\Omega$)'], df['$\Delta$ T (K)'], df['$\Delta$ R ($\Omega$)']
ScatterPlot(xdata, ydata, error_x, error_y, 'purple', 'Temperature (K)', 'Resistance ($\Omega$)')

# %%
# FITTING OUR FUNCTION
x_min, x_max = 100, 180
df_study = df[(df['Temperature (K)'] >= x_min) & (df['Temperature (K)'] <= x_max)]
xdata, ydata, error_x, error_y = df_study['Temperature (K)'], df_study['Resistance ($\Omega$)'], df_study['$\Delta$ T (K)'], df_study['$\Delta$ R ($\Omega$)']
FUNCTION_FIT(xdata, ydata, error_x, error_y, 'red', 'Temperature (K)', 'Resistance ($\Omega$)', Sigmoid)
# Out:
# Corresponding p-value: 0.0
# Degrees of freedom: 49
# FIRST DERIVATIVE
# SECOND DERIVATIVE
# <h2> Model</h2> Model(<lambda>) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>41</td><td></td></tr><tr><td># data points</td><td>52</td><td></td></tr><tr><td># variables</td><td>3</td><td></td></tr><tr><td>chi-square</td><td> 1264.63585</td><td></td></tr><tr><td>reduced chi-square</td><td> 25.8088948</td><td></td></tr><tr><td>Akaike info crit.</td><td> 171.947380</td><td></td></tr><tr><td>Bayesian info crit.</td><td> 177.801111</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> L </td><td>  0.01674935 </td><td>  1.0425e-04 </td><td> (0.62%) </td><td> 0.017528822348271054 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> x0 </td><td>  140.028224 </td><td>  0.07664756 </td><td> (0.05%) </td><td> 140.9906545 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> k </td><td>  1.15713918 </td><td>  0.09141005 </td><td> (7.90%) </td><td> 1 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>x0</td><td>k</td><td>0.1996</td></tr><tr><td>L</td><td>k</td><td>-0.1919</td></tr><tr><td>L</td><td>x0</td><td>0.1885</td></tr></table>

# %% [markdown]
# # WARMING 1

# %%
# READING THE DATA FROM .txt FILES ---------------------------------------
data = CLEAN_INPUT('Week2Files/EvanRenzo_Warming1.txt')
df = pd.DataFrame(data, columns=['I (mA)', 'Voltage (mV)', 'Temperature (K)'])
df['I (mA)'] = df['I (mA)']*1e2
df['Voltage (mV)'] = df['Voltage (mV)']*1e3
df['Resistance ($\Omega$)'] = df['Voltage (mV)']/df['I (mA)']

# ADDING UNCERTAINTIES ---------------------------------------
df['$\Delta$ V (mV)'], df['$\Delta$ I (mA)'], df['$\Delta$ T (K)'] = 0.01, 0.01, 0.01
df['$\Delta$ R ($\Omega$)'] = df.apply(lambda x: uncertainty_var([x['Voltage (mV)'], x['I (mA)']], [x['$\Delta$ V (mV)'], x['$\Delta$ I (mA)']], calculate_R), axis=1)
df.head(5)
# Out:
#        I (mA)  Voltage (mV)  Temperature (K)  Resistance ($\Omega$)  \
# 0  100.058331      0.000505        83.353296               0.000005
# 1  100.052682      0.000382        83.432066               0.000004
# 2  100.058630      0.000986        83.513228               0.000010
# 3  100.059577      0.000960        83.606945               0.000010
# 4  100.056507      0.000666        83.741711               0.000007
#
#    $\Delta$ V (mV)  $\Delta$ I (mA)  $\Delta$ T (K)  $\Delta$ R ($\Omega$)
# 0             0.01             0.01            0.01               0.000095
# 1             0.01             0.01            0.01               0.000096
# 2             0.01             0.01            0.01               0.000090
# 3             0.01             0.01            0.01               0.000090
# 4             0.01             0.01            0.01               0.000093

# %%
# PLOTTING OUR DATA
xdata, ydata, error_x, error_y = df['Temperature (K)'], df['Resistance ($\Omega$)'], df['$\Delta$ T (K)'], df['$\Delta$ R ($\Omega$)']
ScatterPlot(xdata, ydata, error_x, error_y, 'purple', 'Temperature (K)', 'Resistance ($\Omega$)')

# %%
# FITTING OUR FUNCTION
x_min, x_max = 100, 125
df_study = df[(df['Temperature (K)'] >= x_min) & (df['Temperature (K)'] <= x_max)]
xdata, ydata, error_x, error_y = df_study['Temperature (K)'], df_study['Resistance ($\Omega$)'], df_study['$\Delta$ T (K)'], df_study['$\Delta$ R ($\Omega$)']
FUNCTION_FIT(xdata, ydata, error_x, error_y, 'red', 'Temperature (K)', 'Resistance ($\Omega$)', Sigmoid)
# Out:
# Corresponding p-value: 0.7115808640205061
# Degrees of freedom: 104
# <h2> Model</h2> Model(<lambda>) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>26</td><td></td></tr><tr><td># data points</td><td>107</td><td></td></tr><tr><td># variables</td><td>3</td><td></td></tr><tr><td>chi-square</td><td> 95.5226243</td><td></td></tr><tr><td>reduced chi-square</td><td> 0.91848677</td><td></td></tr><tr><td>Akaike info crit.</td><td>-6.14083113</td><td></td></tr><tr><td>Bayesian info crit.</td><td> 1.87765538</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> L </td><td>  0.01212986 </td><td>  3.1126e-05 </td><td> (0.26%) </td><td> 0.011934903261898288 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> x0 </td><td>  115.263811 </td><td>  0.02351522 </td><td> (0.02%) </td><td> 114.080386 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> k </td><td>  0.39315574 </td><td>  0.00288418 </td><td> (0.73%) </td><td> 1 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>L</td><td>x0</td><td>0.7926</td></tr><tr><td>L</td><td>k</td><td>-0.7136</td></tr><tr><td>x0</td><td>k</td><td>-0.5520</td></tr></table>

# %% [markdown]
# # COOLING 2

# %%
# READING THE DATA FROM .txt FILES ---------------------------------------
data = CLEAN_INPUT('Week2Files/EvanRenzo_Cooling2.txt')
df = pd.DataFrame(data, columns=['I (mA)', 'Voltage (mV)', 'Temperature (K)'])
df['I (mA)'] = df['I (mA)']*1e2
df['Voltage (mV)'] = df['Voltage (mV)']*1e3
df['Resistance ($\Omega$)'] = df['Voltage (mV)']/df['I (mA)']

# ADDING UNCERTAINTIES ---------------------------------------
df['$\Delta$ V (mV)'], df['$\Delta$ I (mA)'], df['$\Delta$ T (K)'] = 0.01, 0.01, 0.01
df['$\Delta$ R ($\Omega$)'] = df.apply(lambda x: uncertainty_var([x['Voltage (mV)'], x['I (mA)']], [x['$\Delta$ V (mV)'], x['$\Delta$ I (mA)']], calculate_R), axis=1)
df.head(5)
# Out:
#        I (mA)  Voltage (mV)  Temperature (K)  Resistance ($\Omega$)  \
# 0  100.047285      1.388910       146.120115               0.013883
# 1  100.049743      1.391290       146.208832               0.013906
# 2  100.050312      1.391033       146.287117               0.013903
# 3  100.054598      1.392116       146.342671               0.013914
# 4  100.054230      1.393020       146.385849               0.013923
#
#    $\Delta$ V (mV)  $\Delta$ I (mA)  $\Delta$ T (K)  $\Delta$ R ($\Omega$)
# 0             0.01             0.01            0.01                 0.0001
# 1             0.01             0.01            0.01                 0.0001
# 2             0.01             0.01            0.01                 0.0001
# 3             0.01             0.01            0.01                 0.0001
# 4             0.01             0.01            0.01                 0.0001

# %%
# PLOTTING OUR DATA
xdata, ydata, error_x, error_y = df['Temperature (K)'], df['Resistance ($\Omega$)'], df['$\Delta$ T (K)'], df['$\Delta$ R ($\Omega$)']
ScatterPlot(xdata, ydata, error_x, error_y, 'purple', 'Temperature (K)', 'Resistance ($\Omega$)')

# %%
# FITTING OUR FUNCTION
x_min, x_max = 115, 180
df_study = df[(df['Temperature (K)'] >= x_min) & (df['Temperature (K)'] <= x_max)]
xdata, ydata, error_x, error_y = df_study['Temperature (K)'], df_study['Resistance ($\Omega$)'], df_study['$\Delta$ T (K)'], df_study['$\Delta$ R ($\Omega$)']
FUNCTION_FIT(xdata, ydata, error_x, error_y, 'red', 'Temperature (K)', 'Resistance ($\Omega$)', Sigmoid)
# Out:
# Corresponding p-value: 0.0
# Degrees of freedom: 10
# FIRST DERIVATIVE
# SECOND DERIVATIVE
# <h2> Model</h2> Model(<lambda>) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>51</td><td></td></tr><tr><td># data points</td><td>13</td><td></td></tr><tr><td># variables</td><td>3</td><td></td></tr><tr><td>chi-square</td><td> 220.153335</td><td></td></tr><tr><td>reduced chi-square</td><td> 22.0153335</td><td></td></tr><tr><td>Akaike info crit.</td><td> 42.7818740</td><td></td></tr><tr><td>Bayesian info crit.</td><td> 44.4767221</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> L </td><td>  0.01595120 </td><td>  9.1079e-04 </td><td> (5.71%) </td><td> 0.013934747521086125 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> x0 </td><td>  139.604371 </td><td>  0.66560294 </td><td> (0.48%) </td><td> 144.215171 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> k </td><td>  0.28323627 </td><td>  0.03420196 </td><td> (12.08%) </td><td> 1 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>L</td><td>x0</td><td>0.9285</td></tr><tr><td>L</td><td>k</td><td>-0.9102</td></tr><tr><td>x0</td><td>k</td><td>-0.7768</td></tr></table>

# %% [markdown]
# # WARMING 2

# %%
# READING THE DATA FROM .txt FILES ---------------------------------------
data = CLEAN_INPUT('Week2Files/EvanRenzo_Warming2.txt')
df = pd.DataFrame(data, columns=['I (mA)', 'Voltage (mV)', 'Temperature (K)'])
df['I (mA)'] = df['I (mA)']*1e2
df['Voltage (mV)'] = df['Voltage (mV)']*1e3
df['Resistance ($\Omega$)'] = df['Voltage (mV)']/df['I (mA)']

# ADDING UNCERTAINTIES ---------------------------------------
df['$\Delta$ V (mV)'], df['$\Delta$ I (mA)'], df['$\Delta$ T (K)'] = 0.01, 0.01, 0.01
df['$\Delta$ R ($\Omega$)'] = df.apply(lambda x: uncertainty_var([x['Voltage (mV)'], x['I (mA)']], [x['$\Delta$ V (mV)'], x['$\Delta$ I (mA)']], calculate_R), axis=1)
df.head(5)
# Out:
#        I (mA)  Voltage (mV)  Temperature (K)  Resistance ($\Omega$)  \
# 0  100.063758      0.000313        83.934242               0.000003
# 1  100.059550      0.001238        84.080253               0.000012
# 2  100.063234      0.000126        84.228432               0.000001
# 3  100.059992      0.000564        84.361092               0.000006
# 4  100.063434      0.000789        84.527499               0.000008
#
#    $\Delta$ V (mV)  $\Delta$ I (mA)  $\Delta$ T (K)  $\Delta$ R ($\Omega$)
# 0             0.01             0.01            0.01               0.000097
# 1             0.01             0.01            0.01               0.000088
# 2             0.01             0.01            0.01               0.000099
# 3             0.01             0.01            0.01               0.000094
# 4             0.01             0.01            0.01               0.000092

# %%
# PLOTTING OUR DATA
xdata, ydata, error_x, error_y = df['Temperature (K)'], df['Resistance ($\Omega$)'], df['$\Delta$ T (K)'], df['$\Delta$ R ($\Omega$)']
ScatterPlot(xdata, ydata, error_x, error_y, 'purple', 'Temperature (K)', 'Resistance ($\Omega$)')

# %%
# FITTING OUR FUNCTION
x_min, x_max = 100, 125
df_study = df[(df['Temperature (K)'] >= x_min) & (df['Temperature (K)'] <= x_max)]
xdata, ydata, error_x, error_y = df_study['Temperature (K)'], df_study['Resistance ($\Omega$)'], df_study['$\Delta$ T (K)'], df_study['$\Delta$ R ($\Omega$)']
FUNCTION_FIT(xdata, ydata, error_x, error_y, 'red', 'Temperature (K)', 'Resistance ($\Omega$)', Sigmoid)
# Out:
# Corresponding p-value: 0.9898107509620144
# Degrees of freedom: 102
# <h2> Model</h2> Model(<lambda>) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>33</td><td></td></tr><tr><td># data points</td><td>105</td><td></td></tr><tr><td># variables</td><td>3</td><td></td></tr><tr><td>chi-square</td><td> 71.8167117</td><td></td></tr><tr><td>reduced chi-square</td><td> 0.70408541</td><td></td></tr><tr><td>Akaike info crit.</td><td>-33.8835306</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-25.9216495</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> L </td><td>  0.01197809 </td><td>  9.8709e-05 </td><td> (0.82%) </td><td> 0.010231554313400377 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> x0 </td><td>  117.775432 </td><td>  0.05266374 </td><td> (0.04%) </td><td> 112.313083 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> k </td><td>  0.39544249 </td><td>  0.00401721 </td><td> (1.02%) </td><td> 1 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>L</td><td>x0</td><td>0.9729</td></tr><tr><td>L</td><td>k</td><td>-0.8719</td></tr><tr><td>x0</td><td>k</td><td>-0.8580</td></tr></table>

# %% [markdown]
# # COOLING 3

# %%
# READING THE DATA FROM .txt FILES ---------------------------------------
data = CLEAN_INPUT('Week2Files/EvanRenzo_Cooling3.txt')
df = pd.DataFrame(data, columns=['I (mA)', 'Voltage (mV)', 'Temperature (K)'])
df['I (mA)'] = df['I (mA)']*1e2
df['Voltage (mV)'] = df['Voltage (mV)']*1e3
df['Resistance ($\Omega$)'] = df['Voltage (mV)']/df['I (mA)']

# ADDING UNCERTAINTIES ---------------------------------------
df['$\Delta$ V (mV)'], df['$\Delta$ I (mA)'], df['$\Delta$ T (K)'] = 0.01, 0.01, 0.01
df['$\Delta$ R ($\Omega$)'] = df.apply(lambda x: uncertainty_var([x['Voltage (mV)'], x['I (mA)']], [x['$\Delta$ V (mV)'], x['$\Delta$ I (mA)']], calculate_R), axis=1)
df.head(5)
# Out:
#        I (mA)  Voltage (mV)  Temperature (K)  Resistance ($\Omega$)  \
# 0  100.065905      1.135764       124.280172               0.011350
# 1  100.067697      1.138462       124.407228               0.011377
# 2  100.063756      1.131784       124.405161               0.011311
# 3  100.064517      0.580916       123.761391               0.005805
# 4  100.060299      0.047653       121.229469               0.000476
#
#    $\Delta$ V (mV)  $\Delta$ I (mA)  $\Delta$ T (K)  $\Delta$ R ($\Omega$)
# 0             0.01             0.01            0.01                 0.0001
# 1             0.01             0.01            0.01                 0.0001
# 2             0.01             0.01            0.01                 0.0001
# 3             0.01             0.01            0.01                 0.0001
# 4             0.01             0.01            0.01                 0.0001

# %%
# PLOTTING OUR DATA
xdata, ydata, error_x, error_y = df['Temperature (K)'], df['Resistance ($\Omega$)'], df['$\Delta$ T (K)'], df['$\Delta$ R ($\Omega$)']
ScatterPlot(xdata, ydata, error_x, error_y, 'purple', 'Temperature (K)', 'Resistance ($\Omega$)')

# %%
# FITTING OUR FUNCTION
x_min, x_max = 100, 125
df_study = df[(df['Temperature (K)'] >= x_min) & (df['Temperature (K)'] <= x_max)]
xdata, ydata, error_x, error_y = df_study['Temperature (K)'], df_study['Resistance ($\Omega$)'], df_study['$\Delta$ T (K)'], df_study['$\Delta$ R ($\Omega$)']
FUNCTION_FIT(xdata, ydata, error_x, error_y, 'red', 'Temperature (K)', 'Resistance ($\Omega$)', Sigmoid)
# Out:
# Corresponding p-value: 5.409655413624037e-07
# Degrees of freedom: 5
# <h2> Model</h2> Model(<lambda>) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>110</td><td></td></tr><tr><td># data points</td><td>8</td><td></td></tr><tr><td># variables</td><td>3</td><td></td></tr><tr><td>chi-square</td><td> 37.2205332</td><td></td></tr><tr><td>reduced chi-square</td><td> 7.44410664</td><td></td></tr><tr><td>Akaike info crit.</td><td> 18.2993523</td><td></td></tr><tr><td>Bayesian info crit.</td><td> 18.5376769</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> L </td><td>  0.01134590 </td><td>  1.9845e-04 </td><td> (1.75%) </td><td> 0.011376919266963844 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> x0 </td><td>  123.759915 </td><td>  23.4289959 </td><td> (18.93%) </td><td> 122.49543 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> k </td><td>  31.5982918 </td><td>  468586.771 </td><td> (1482949.69%) </td><td> 1 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>x0</td><td>k</td><td>1.0000</td></tr><tr><td>L</td><td>k</td><td>-0.6088</td></tr><tr><td>L</td><td>x0</td><td>-0.6088</td></tr></table>

# %% [markdown]
# # WARMING 3

# %%
# READING THE DATA FROM .txt FILES ---------------------------------------
data = CLEAN_INPUT('Week2Files/EvanRenzo_Warming3.txt')
df = pd.DataFrame(data, columns=['I (mA)', 'Voltage (mV)', 'Temperature (K)'])
df['I (mA)'] = df['I (mA)']*1e2
df['Voltage (mV)'] = df['Voltage (mV)']*1e3
df['Resistance ($\Omega$)'] = df['Voltage (mV)']/df['I (mA)']

# ADDING UNCERTAINTIES ---------------------------------------
df['$\Delta$ V (mV)'], df['$\Delta$ I (mA)'], df['$\Delta$ T (K)'] = 0.01, 0.01, 0.01
df['$\Delta$ R ($\Omega$)'] = df.apply(lambda x: uncertainty_var([x['Voltage (mV)'], x['I (mA)']], [x['$\Delta$ V (mV)'], x['$\Delta$ I (mA)']], calculate_R), axis=1)
df.head(5)
# Out:
#        I (mA)  Voltage (mV)  Temperature (K)  Resistance ($\Omega$)  \
# 0  100.070206      0.001719        87.767164               0.000017
# 1  100.071933      0.001649        87.974368               0.000016
# 2  100.071694      0.002280        88.169867               0.000023
# 3  100.071198      0.001360        88.367720               0.000014
# 4  100.065245      0.000954        88.571287               0.000010
#
#    $\Delta$ V (mV)  $\Delta$ I (mA)  $\Delta$ T (K)  $\Delta$ R ($\Omega$)
# 0             0.01             0.01            0.01               0.000083
# 1             0.01             0.01            0.01               0.000083
# 2             0.01             0.01            0.01               0.000077
# 3             0.01             0.01            0.01               0.000086
# 4             0.01             0.01            0.01               0.000090

# %%
# PLOTTING OUR DATA
xdata, ydata, error_x, error_y = df['Temperature (K)'], df['Resistance ($\Omega$)'], df['$\Delta$ T (K)'], df['$\Delta$ R ($\Omega$)']
ScatterPlot(xdata, ydata, error_x, error_y, 'purple', 'Temperature (K)', 'Resistance ($\Omega$)')

# %%
# FITTING OUR FUNCTION
x_min, x_max = 100, 125
df_study = df[(df['Temperature (K)'] >= x_min) & (df['Temperature (K)'] <= x_max)]
xdata, ydata, error_x, error_y = df_study['Temperature (K)'], df_study['Resistance ($\Omega$)'], df_study['$\Delta$ T (K)'], df_study['$\Delta$ R ($\Omega$)']
FUNCTION_FIT(xdata, ydata, error_x, error_y, 'red', 'Temperature (K)', 'Resistance ($\Omega$)', Sigmoid)
# Out:
# Corresponding p-value: 0.4379549827982727
# Degrees of freedom: 105
# <h2> Model</h2> Model(<lambda>) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>33</td><td></td></tr><tr><td># data points</td><td>108</td><td></td></tr><tr><td># variables</td><td>3</td><td></td></tr><tr><td>chi-square</td><td> 106.604896</td><td></td></tr><tr><td>reduced chi-square</td><td> 1.01528472</td><td></td></tr><tr><td>Akaike info crit.</td><td> 4.59580646</td><td></td></tr><tr><td>Bayesian info crit.</td><td> 12.6422001</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> L </td><td>  0.01201384 </td><td>  5.1113e-05 </td><td> (0.43%) </td><td> 0.011451346663695731 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> x0 </td><td>  117.226253 </td><td>  0.03185547 </td><td> (0.03%) </td><td> 113.929753 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> k </td><td>  0.40845351 </td><td>  0.00369619 </td><td> (0.90%) </td><td> 1 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>L</td><td>x0</td><td>0.8902</td></tr><tr><td>L</td><td>k</td><td>-0.7901</td></tr><tr><td>x0</td><td>k</td><td>-0.6890</td></tr></table>

# %% [markdown]
# # COOLING 4

# %%
# READING THE DATA FROM .txt FILES ---------------------------------------
data = CLEAN_INPUT('Week2Files/EvanRenzo_Cooling4.txt')
df = pd.DataFrame(data, columns=['I (mA)', 'Voltage (mV)', 'Temperature (K)'])
df['I (mA)'] = df['I (mA)']*1e2
df['Voltage (mV)'] = df['Voltage (mV)']*1e3
df['Resistance ($\Omega$)'] = df['Voltage (mV)']/df['I (mA)']

# ADDING UNCERTAINTIES ---------------------------------------
df['$\Delta$ V (mV)'], df['$\Delta$ I (mA)'], df['$\Delta$ T (K)'] = 0.01, 0.01, 0.01
df['$\Delta$ R ($\Omega$)'] = df.apply(lambda x: uncertainty_var([x['Voltage (mV)'], x['I (mA)']], [x['$\Delta$ V (mV)'], x['$\Delta$ I (mA)']], calculate_R), axis=1)
df.head(5)
# Out:
#        I (mA)  Voltage (mV)  Temperature (K)  Resistance ($\Omega$)  \
# 0  100.076987      1.201376       126.968849               0.012005
# 1  100.074461      1.204492       127.112873               0.012036
# 2  100.072488      1.067273       127.082670               0.010665
# 3  100.077886      0.662859       125.465678               0.006623
# 4  100.074009      0.115860       121.103460               0.001158
#
#    $\Delta$ V (mV)  $\Delta$ I (mA)  $\Delta$ T (K)  $\Delta$ R ($\Omega$)
# 0             0.01             0.01            0.01                 0.0001
# 1             0.01             0.01            0.01                 0.0001
# 2             0.01             0.01            0.01                 0.0001
# 3             0.01             0.01            0.01                 0.0001
# 4             0.01             0.01            0.01                 0.0001

# %%
# PLOTTING OUR DATA
xdata, ydata, error_x, error_y = df['Temperature (K)'], df['Resistance ($\Omega$)'], df['$\Delta$ T (K)'], df['$\Delta$ R ($\Omega$)']
ScatterPlot(xdata, ydata, error_x, error_y, 'purple', 'Temperature (K)', 'Resistance ($\Omega$)')

# %%
# FITTING OUR FUNCTION
x_min, x_max = 100, 125
df_study = df[(df['Temperature (K)'] >= x_min) & (df['Temperature (K)'] <= x_max)]
xdata, ydata, error_x, error_y = df_study['Temperature (K)'], df_study['Resistance ($\Omega$)'], df_study['$\Delta$ T (K)'], df_study['$\Delta$ R ($\Omega$)']
FUNCTION_FIT(xdata, ydata, error_x, error_y, 'red', 'Temperature (K)', 'Resistance ($\Omega$)', Sigmoid)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-7f6c1fe69d01> in <module>
#       3 df_study = df[(df['Temperature (K)'] >= x_min) & (df['Temperature (K)'] <= x_max)]
#       4 xdata, ydata, error_x, error_y = df_study['Temperature (K)'], df_study['Resistance ($\Omega$)'], df_study['$\Delta$ T (K)'], df_study['$\Delta$ R ($\Omega$)']
# ----> 5 FUNCTION_FIT(xdata, ydata, error_x, error_y, 'red', 'Temperature (K)', 'Resistance ($\Omega$)', Sigmoid)
#
# <ipython-input-4-180531745d20> in FUNCTION_FIT(xdata, ydata, error_x, error_y, color, x_label, y_label, function)
#      72     L ,x0, k = result.params['L'].value, result.params['x0'].value, result.params['k'].value
#      73     dx0 = result.params['x0'].stderr
# ---> 74     label = r'$\textit{(' + str("{:.5}".format(x0)) + '±' + str("{:.2}".format(dx0)) + ') K}$'
#      75     #plt.plot(xdata,result.best_fit, color=color)
#      76     x = np.arange(xdata.min(), xdata.max(), (xdata.max()-xdata.min())/1000)
#
# TypeError: unsupported format string passed to NoneType.__format__

# %%
# READING THE DATA FROM .txt FILES ---------------------------------------
data = CLEAN_INPUT('Week2Files/EvanRenzo_Warming4.txt')
df = pd.DataFrame(data, columns=['I (mA)', 'Voltage (mV)', 'Temperature (K)'])
df['I (mA)'] = df['I (mA)']*1e2
df['Voltage (mV)'] = df['Voltage (mV)']*1e3
df['Resistance ($\Omega$)'] = df['Voltage (mV)']/df['I (mA)']

# ADDING UNCERTAINTIES ---------------------------------------
df['$\Delta$ V (mV)'], df['$\Delta$ I (mA)'], df['$\Delta$ T (K)'] = 0.01, 0.01, 0.01
df['$\Delta$ R ($\Omega$)'] = df.apply(lambda x: uncertainty_var([x['Voltage (mV)'], x['I (mA)']], [x['$\Delta$ V (mV)'], x['$\Delta$ I (mA)']], calculate_R), axis=1)
df.head(5)
# Out:
#        I (mA)  Voltage (mV)  Temperature (K)  Resistance ($\Omega$)  \
# 0  100.067721      0.000580        82.448578           5.797178e-06
# 1  100.070905      0.000874        82.565718           8.734279e-06
# 2  100.070495      0.000094        82.668089           9.360943e-07
# 3  100.077036      0.000580        82.769397           5.796981e-06
# 4  100.073044      0.000703        82.855812           7.025548e-06
#
#    $\Delta$ V (mV)  $\Delta$ I (mA)  $\Delta$ T (K)  $\Delta$ R ($\Omega$)
# 0             0.01             0.01            0.01               0.000094
# 1             0.01             0.01            0.01               0.000091
# 2             0.01             0.01            0.01               0.000099
# 3             0.01             0.01            0.01               0.000094
# 4             0.01             0.01            0.01               0.000093

# %%
# PLOTTING OUR DATA
xdata, ydata, error_x, error_y = df['Temperature (K)'], df['Resistance ($\Omega$)'], df['$\Delta$ T (K)'], df['$\Delta$ R ($\Omega$)']
ScatterPlot(xdata, ydata, error_x, error_y, 'purple', 'Temperature (K)', 'Resistance ($\Omega$)')

# %% [markdown]
# ***
# ### <font color=green>BUCKET 2 (NO SUPERCONDUCTOR)</font>
# ***

# %%
# READING THE DATA FROM .txt FILES ---------------------------------------
data = CLEAN_INPUT('Week2Files/EvanRenzo_NS_Cooling1.txt')
df = pd.DataFrame(data, columns=['I (mA)', 'Voltage (mV)', 'Temperature (K)'])
df['I (mA)'] = df['I (mA)']*1e2
df['Voltage (mV)'] = df['Voltage (mV)']*1e3
df['Resistance ($\Omega$)'] = df['Voltage (mV)']/df['I (mA)']

# ADDING UNCERTAINTIES ---------------------------------------
df['$\Delta$ V (mV)'], df['$\Delta$ I (mA)'], df['$\Delta$ T (K)'] = 0.01, 0.01, 0.01
df['$\Delta$ R ($\Omega$)'] = df.apply(lambda x: uncertainty_var([x['Voltage (mV)'], x['I (mA)']], [x['$\Delta$ V (mV)'], x['$\Delta$ I (mA)']], calculate_R), axis=1)
df.head(5)
# Out:
#        I (mA)  Voltage (mV)  Temperature (K)  Resistance ($\Omega$)  \
# 0  998.941631    306.147303       220.535324               0.306472
# 1  998.939564    306.214225       220.553682               0.306539
# 2  998.815898    306.202823       220.565898               0.306566
# 3  998.775125    306.240828       220.572254               0.306616
# 4  998.837460    306.289571       220.599369               0.306646
#
#    $\Delta$ V (mV)  $\Delta$ I (mA)  $\Delta$ T (K)  $\Delta$ R ($\Omega$)
# 0             0.01             0.01            0.01                0.00001
# 1             0.01             0.01            0.01                0.00001
# 2             0.01             0.01            0.01                0.00001
# 3             0.01             0.01            0.01                0.00001
# 4             0.01             0.01            0.01                0.00001

# %%
# PLOTTING OUR DATA
xdata, ydata, error_x, error_y = df['Temperature (K)'], df['Resistance ($\Omega$)'], df['$\Delta$ T (K)'], df['$\Delta$ R ($\Omega$)']
ScatterPlot(xdata, ydata, error_x, error_y, 'purple', 'Temperature (K)', 'Resistance ($\Omega$)')

# %%
# READING THE DATA FROM .txt FILES ---------------------------------------
data = CLEAN_INPUT('Week2Files/EvanRenzo_NS_Warming1.txt')
df = pd.DataFrame(data, columns=['I (mA)', 'Voltage (mV)', 'Temperature (K)'])
df['I (mA)'] = df['I (mA)']*1e2
df['Voltage (mV)'] = df['Voltage (mV)']*1e3
df['Resistance ($\Omega$)'] = df['Voltage (mV)']/df['I (mA)']

# ADDING UNCERTAINTIES ---------------------------------------
df['$\Delta$ V (mV)'], df['$\Delta$ I (mA)'], df['$\Delta$ T (K)'] = 0.01, 0.01, 0.01
df['$\Delta$ R ($\Omega$)'] = df.apply(lambda x: uncertainty_var([x['Voltage (mV)'], x['I (mA)']], [x['$\Delta$ V (mV)'], x['$\Delta$ I (mA)']], calculate_R), axis=1)
df.head(5)
# Out:
#        I (mA)  Voltage (mV)  Temperature (K)  Resistance ($\Omega$)  \
# 0  100.085860    189.518018       142.976582               1.893554
# 1  100.106054    189.483372       143.027465               1.892826
# 2  100.102623    189.450898       143.078999               1.892567
# 3  100.106696    189.413104       143.115365               1.892112
# 4  100.094269    189.353296       143.161940               1.891750
#
#    $\Delta$ V (mV)  $\Delta$ I (mA)  $\Delta$ T (K)  $\Delta$ R ($\Omega$)
# 0             0.01             0.01            0.01               0.000214
# 1             0.01             0.01            0.01               0.000214
# 2             0.01             0.01            0.01               0.000214
# 3             0.01             0.01            0.01               0.000214
# 4             0.01             0.01            0.01               0.000214

# %%
# PLOTTING OUR DATA
xdata, ydata, error_x, error_y = df['Temperature (K)'], df['Resistance ($\Omega$)'], df['$\Delta$ T (K)'], df['$\Delta$ R ($\Omega$)']
ScatterPlot(xdata, ydata, error_x, error_y, 'purple', 'Temperature (K)', 'Resistance ($\Omega$)')
